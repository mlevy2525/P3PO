# %%
import cv2
from pathlib import Path
# If you want to read a video file set the path under path, 
# If you want to use a specific image set use_video to False and give the image path under path
#TODO: Set the path to the video file or image file
use_video = False
path = "/home/aadhithya/bobby_wks/P3PO/coordinates/images/cam4_robot_place_bottle_8p.png"

# TODO: If you have an open teach pickle you can use that instead of the video/image, set use_pickle to True and set the path/pixel_key
# If the image that shows at the bottom is bgr set original_bgr to True
use_pickle = False
pickle_path = "/home/aadhithya/bobby_wks/P3PO/expert_demos/xarm_env/0105_place_side_door_bottle_on_ground.pkl"
# pickle_path = "/home/aadhithya/bobby_wks/P3PO/expert_demos/xarm_env/pick_white_plate_cam2.pkl"
pixel_key = "pixels4"
original_bgr = False

#TODO: Set the task name here -- this will be used to save the output
task_name = "cam4_robot_place_fridge_bottle"

if use_pickle:
    import pickle
    with open(pickle_path, 'rb') as f:
        data = pickle.load(f)
    img = data['observations'][0][pixel_key][0]
    use_video = False
    if original_bgr:
        img = img[:,:,::-1]
    # save image
    cv2.imwrite(f"/home/aadhithya/bobby_wks/cam4_robot_place_side_door_bottle.png", img)
    exit()
else:
    img = None
    if use_video:
        cap = cv2.VideoCapture(path)
        while(cap.isOpened()):
            ret, frame = cap.read()
            img = frame.copy()
            break
    else:
        img = cv2.imread(path)
        shape = img.shape
        print(shape)
        # # crop image to the right half
        # img = img[160:240, 210:270]
    # We flip here because CV2 reads in as BGR
    img = img[:,:,::-1]

#TODO: If its hard to see the image, you can increase the size_multiplier, this won't affect the selected coordinates
size_multiplier = 1

coordinates_path = f"../../coordinates"
# Out:
# (340, 275, 3)

# %%
# %gui asyncio

import os
from PIL import Image

import numpy as np
from IPython.display import display, Javascript
import ipywidgets as widgets
from ipycanvas import Canvas, hold_canvas
import pickle

import io
import asyncio
import logging


# Define an async function to wait for button click
async def wait_for_click(button):
    # Create a future object
    future = asyncio.Future()
    # Define the click event handler
    def on_button_clicked(b):
        future.set_result(None)
    # Attach the event handler to the button
    button.on_click(on_button_clicked)
    # Wait until the future is set
    await future

class Points():
    def __init__(self, env_name, img, coordinates_path, size_multiplier=1):
        logging.getLogger().setLevel(logging.DEBUG)
        logging.info("Starting the Points class")
        self.img = img
        self.size_multiplier = size_multiplier
        self.coordinates_path = coordinates_path
        self.env_name = env_name

        # Save the image to a bytes buffer
        image = Image.fromarray(self.img)
        size = img.shape
        print(size)
        image = image.resize((size[1] * self.size_multiplier, size[0] * self.size_multiplier))
        buffer = io.BytesIO()
        image.save(buffer, format='PNG')
        buffer.seek(0)

        # Create an IPyWidgets Image widget
        self.canvas = Canvas(width=size[1] * self.size_multiplier, height=size[0] * self.size_multiplier)
        # Define the size of each cell

        self.canvas.put_image_data(np.array(image), 0, 0)

        # Display coordinates
        coords_label = widgets.Label(value="Click on the image to select the coordinates")

        # Define the click event handler
        self.coords = []
        def on_click(x, y):
            coords_label.value = f"Coordinates: ({x}, {y})"
            self.coords.append((0, x, y))

            with hold_canvas(self.canvas):
                self.canvas.put_image_data(np.array(image), 0, 0)  # Redraw the original image

                self.canvas.fill_style = 'red'
                for coord in self.coords:
                    x, y = coord[1] // self.size_multiplier, coord[2] // self.size_multiplier
                    self.canvas.fill_circle(x, y, 2)

        # Connect the click event to the handler
        self.canvas.on_mouse_down(on_click)

        self.button = widgets.Button(description="Save Points")

        # Display the widgets
        self.vbox = widgets.VBox([self.canvas, coords_label, self.button])

        # # Display the widget
        display(self.vbox)

    def on_done(self):
        logging.info("saving")
        Path(self.coordinates_path + "/coords/").mkdir(parents=True, exist_ok=True)
        with open(self.coordinates_path + "/coords/" + self.env_name + ".pkl", 'wb') as f:
            try:
                pickle.dump(self.coords, f)
            except Exception as e:
                logging.info(e)
        Path(self.coordinates_path + "/images/").mkdir(parents=True, exist_ok=True)
        with open(self.coordinates_path + "/images/" + self.env_name + ".png", 'wb') as f:
            try:
                image = Image.fromarray(self.img)
                image.save(f)
            except Exception as e:
                logging.info(e)
        logging.info("saved")

# %%
async def f():
    point = Points(task_name, img, coordinates_path, size_multiplier)
    x = await wait_for_click(point.button)
    point.vbox.close()
    point.canvas.close()
    point.on_done()
asyncio.ensure_future(f())
# Out:
# <Task pending name='Task-8' coro=<f() running at /tmp/ipykernel_1008451/3187731821.py:1>>
# INFO:root:Starting the Points class
# (340, 275, 3)
# VBox(children=(Canvas(height=340, width=275), Label(value='Click on the image to select the coordinates'), But…
# DEBUG:Comm:handle_msg[d4cf2278f4c740299a7abc968a8aeba2]({'header': {'date': datetime.datetime(2025, 1, 5, 12, 24, 24, 987000, tzinfo=tzutc()), 'msg_id': 'f798a643-e6c1-4776-a487-d8266ba5e23e', 'msg_type': 'comm_msg', 'session': 'f8fd1fda-52da-45aa-b2e6-90a7650f0e3a', 'username': '4c80f49d-0a5b-4b83-a405-c265b0e97cf0', 'version': '5.2'}, 'msg_id': 'f798a643-e6c1-4776-a487-d8266ba5e23e', 'msg_type': 'comm_msg', 'parent_header': {}, 'metadata': {}, 'content': {'comm_id': 'd4cf2278f4c740299a7abc968a8aeba2', 'data': {'method': 'custom', 'content': {'event': 'client_ready'}}}, 'buffers': []})
# DEBUG:Comm:handle_msg[d4cf2278f4c740299a7abc968a8aeba2]({'header': {'date': datetime.datetime(2025, 1, 5, 12, 24, 27, 119000, tzinfo=tzutc()), 'msg_id': 'bf9fb25c-055a-499b-bccb-31c5c9ecc284', 'msg_type': 'comm_msg', 'session': 'f8fd1fda-52da-45aa-b2e6-90a7650f0e3a', 'username': '4c80f49d-0a5b-4b83-a405-c265b0e97cf0', 'version': '5.2'}, 'msg_id': 'bf9fb25c-055a-499b-bccb-31c5c9ecc284', 'msg_type': 'comm_msg', 'parent_header': {}, 'metadata': {}, 'content': {'comm_id': 'd4cf2278f4c740299a7abc968a8aeba2', 'data': {'method': 'custom', 'content': {'event': 'mouse_move', 'x': 100.99478147423353, 'y': 212.57357669288223}}}, 'buffers': []})
# DEBUG:Comm:handle_msg[d4cf2278f4c740299a7abc968a8aeba2]({'header': {'date': datetime.datetime(2025, 1, 5, 12, 24, 27, 126000, tzinfo=tzutc()), 'msg_id': 'e67e1f80-fc1b-4f25-9b2f-a598f8b4fe5d', 'msg_type': 'comm_msg', 'session': 'f8fd1fda-52da-45aa-b2e6-90a7650f0e3a', 'username': '4c80f49d-0a5b-4b83-a405-c265b0e97cf0', 'version': '5.2'}, 'msg_id': 'e67e1f80-fc1b-4f25-9b2f-a598f8b4fe5d', 'msg_type': 'comm_msg', 'parent_header': {}, 'metadata': {}, 'content': {'comm_id': 'd4cf2278f4c740299a7abc968a8aeba2', 'data': {'method': 'custom', 'content': {'event': 'mouse_move', 'x': 101.17416829745596, 'y': 212.57357669288223}}}, 'buffers': []})
# DEBUG:Comm:handle_msg[d4cf2278f4c740299a7abc968a8aeba2]({'header': {'date': datetime.datetime(2025, 1, 5, 12, 24, 27, 135000, tzinfo=tzutc()), 'msg_id': '17e7dccc-f239-4b68-bfac-93dc0358519f', 'msg_type': 'comm_msg', 'session': 'f8fd1fda-52da-45aa-b2e6-90a7650f0e3a', 'username': '4c80f49d-0a5b-4b83-a405-c265b0e97cf0', 'version': '5.2'}, 'msg_id': '17e7dccc-f239-4b68-bfac-93dc0358519f', 'msg_type': 'comm_msg', 'parent_header': {}, 'metadata': {}, 'content': {'comm_id': 'd4cf2278f4c740299a7abc968a8aeba2', 'data': {'method': 'custom', 'content': {'event': 'mouse_move', 'x': 101.35355512067841, 'y': 221.54292592043}}}, 'buffers': []})
# DEBUG:Comm:handle_msg[d4cf2278f4c740299a7abc968a8aeba2]({'header': {'date': datetime.datetime(2025, 1, 5, 12, 24, 27, 151000, tzinfo=tzutc()), 'msg_id': 'e20a677d-dbc0-4787-a2fd-4c57fd2782ba', 'msg_type': 'comm_msg', 'session': 'f8fd1fda-52da-45aa-b2e6-90a7650f0e3a', 'username': '4c80f49d-0a5b-4b83-a405-c265b0e97cf0', 'version': '5.2'}, 'msg_id': 'e20a677d-dbc0-4787-a2fd-4c57fd2782ba', 'msg_type': 'comm_msg', 'parent_header': {}, 'metadata': {}, 'content': {'comm_id': 'd4cf2278f4c740299a7abc968a8aeba2', 'data': {'method': 'custom', 'content': {'event': 'mouse_move', 'x': 101.53294194390085, 'y': 221.54292592043}}}, 'buffers': []})
# DEBUG:Comm:handle_msg[d4cf2278f4c740299a7abc968a8aeba2]({'header': {'date': datetime.datetime(2025, 1, 5, 12, 24, 27, 160000, tzinfo=tzutc()), 'msg_id': 'a429ec1a-c2db-4334-8987-5f30ae6a3b4c', 'msg_type': 'comm_msg', 'session': 'f8fd1fda-52da-45aa-b2e6-90a7650f0e3a', 'username': '4c80f49d-0a5b-4b83-a405-c265b0e97cf0', 'version': '5.2'}, 'msg_id': 'a429ec1a-c2db-4334-8987-5f30ae6a3b4c', 'msg_type': 'comm_msg', 'parent_header': {}, 'metadata': {}, 'content': {'comm_id': 'd4cf2278f4c740299a7abc968a8aeba2', 'data': {'method': 'custom', 'content': {'event': 'mouse_move', 'x': 101.53294194390085, 'y': 221.36353893587903}}}, 'buffers': []})
# DEBUG:Comm:handle_msg[d4cf2278f4c740299a7abc968a8aeba2]({'header': {'date': datetime.datetime(2025, 1, 5, 12, 24, 27, 169000, tzinfo=tzutc()), 'msg_id': 'b679f50c-0f84-425a-af9d-c35b43a91389', 'msg_type': 'comm_msg', 'session': 'f8fd1fda-52da-45aa-b2e6-90a7650f0e3a', 'username': '4c80f49d-0a5b-4b83-a405-c265b0e97cf0', 'version': '5.2'}, 'msg_id': 'b679f50c-0f84-425a-af9d-c35b43a91389', 'msg_type': 'comm_msg', 'parent_header': {}, 'metadata': {}, 'content': {'comm_id': 'd4cf2278f4c740299a7abc968a8aeba2', 'data': {'method': 'custom', 'content': {'event': 'mouse_move', 'x': 101.89171559034573, 'y': 221.36353893587903}}}, 'buffers': []})
# DEBUG:Comm:handle_msg[d4cf2278f4c740299a7abc968a8aeba2]({'header': {'date': datetime.datetime(2025, 1, 5, 12, 24, 27, 177000, tzinfo=tzutc()), 'msg_id': '405a5ae7-f631-4173-933c-dea7375ee94f', 'msg_type': 'comm_msg', 'session': 'f8fd1fda-52da-45aa-b2e6-90a7650f0e3a', 'username': '4c80f49d-0a5b-4b83-a405-c265b0e97cf0', 'version': '5.2'}, 'msg_id': '405a5ae7-f631-4173-933c-dea7375ee94f', 'msg_type': 'comm_msg', 'parent_header': {}, 'metadata': {}, 'content': {'comm_id': 'd4cf2278f4c740299a7abc968a8aeba2', 'data': {'method': 'custom', 'content': {'event': 'mouse_move', 'x': 102.25048923679061, 'y': 221.1841519513281}}}, 'buffers': []})
# DEBUG:Comm:handle_msg[d4cf2278f4c740299a7abc968a8aeba2]({'header': {'date': datetime.datetime(2025, 1, 5, 12, 24, 27, 185000, tzinfo=tzutc()), 'msg_id': '3c49dbc9-fbbb-4b95-93a9-97bf11b72c14', 'msg_type': 'comm_msg', 'session': 'f8fd1fda-52da-45aa-b2e6-90a7650f0e3a', 'username': '4c80f49d-0a5b-4b83-a405-c265b0e97cf0', 'version': '5.2'}, 'msg_id': '3c49dbc9-fbbb-4b95-93a9-97bf11b72c14', 'msg_type': 'comm_msg', 'parent_header': {}, 'metadata': {}, 'content': {'comm_id': 'd4cf2278f4c740299a7abc968a8aeba2', 'data': {'method': 'custom', 'content': {'event': 'mouse_move', 'x': 102.60926288323549, 'y': 221.00476496677715}}}, 'buffers': []})
# DEBUG:Comm:handle_msg[d4cf2278f4c740299a7abc968a8aeba2]({'header': {'date': datetime.datetime(2025, 1, 5, 12, 24, 27, 193000, tzinfo=tzutc()), 'msg_id': 'fad0f7e1-8f2a-4fe0-93e5-27cae30a2990', 'msg_type': 'comm_msg', 'session': 'f8fd1fda-52da-45aa-b2e6-90a7650f0e3a', 'username': '4c80f49d-0a5b-4b83-a405-c265b0e97cf0', 'version': '5.2'}, 'msg_id': 'fad0f7e1-8f2a-4fe0-93e5-27cae30a2990', 'msg_type': 'comm_msg', 'parent_header': {}, 'metadata': {}, 'content': {'comm_id': 'd4cf2278f4c740299a7abc968a8aeba2', 'data': {'method': 'custom', 'content': {'event': 'mouse_move', 'x': 103.32681017612525, 'y': 220.64599099767523}}}, 'buffers': []})
# DEBUG:Comm:handle_msg[d4cf2278f4c740299a7abc968a8aeba2]({'header': {'date': datetime.datetime(2025, 1, 5, 12, 24, 27, 201000, tzinfo=tzutc()), 'msg_id': '851fb0ea-3c3b-44a3-8b50-3075f2e22def', 'msg_type': 'comm_msg', 'session': 'f8fd1fda-52da-45aa-b2e6-90a7650f0e3a', 'username': '4c80f49d-0a5b-4b83-a405-c265b0e97cf0', 'version': '5.2'}, 'msg_id': '851fb0ea-3c3b-44a3-8b50-3075f2e22def', 'msg_type': 'comm_msg', 'parent_header': {}, 'metadata': {}, 'content': {'comm_id': 'd4cf2278f4c740299a7abc968a8aeba2', 'data': {'method': 'custom', 'content': {'event': 'mouse_move', 'x': 104.40313111545989, 'y': 220.46660401312428}}}, 'buffers': []})
# DEBUG:Comm:handle_msg[d4cf2278f4c740299a7abc968a8aeba2]({'header': {'date': datetime.datetime(2025, 1, 5, 12, 24, 27, 210000, tzinfo=tzutc()), 'msg_id': 'b67c167f-1c3c-42db-8fec-f750715d5ed9', 'msg_type': 'comm_msg', 'session': 'f8fd1fda-52da-45aa-b2e6-90a7650f0e3a', 'username': '4c80f49d-0a5b-4b83-a405-c265b0e97cf0', 'version': '5.2'}, 'msg_id': 'b67c167f-1c3c-42db-8fec-f750715d5ed9', 'msg_type': 'comm_msg', 'parent_header': {}, 'metadata': {}, 'content': {'comm_id': 'd4cf2278f4c740299a7abc968a8aeba2', 'data': {'method': 'custom', 'content': {'event': 'mouse_wheel', 'x': 0, 'y': 100}}}, 'buffers': []})
# DEBUG:Comm:handle_msg[d4cf2278f4c740299a7abc968a8aeba2]({'header': {'date': datetime.datetime(2025, 1, 5, 12, 24, 27, 210000, tzinfo=tzutc()), 'msg_id': '74742873-659b-451b-bdfa-a6634aa25e2a', 'msg_type': 'comm_msg', 'session': 'f8fd1fda-52da-45aa-b2e6-90a7650f0e3a', 'username': '4c80f49d-0a5b-4b83-a405-c265b0e97cf0', 'version': '5.2'}, 'msg_id': '74742873-659b-451b-bdfa-a6634aa25e2a', 'msg_type': 'comm_msg', 'parent_header': {}, 'metadata': {}, 'content': {'comm_id': 'd4cf2278f4c740299a7abc968a8aeba2', 'data': {'method': 'custom', 'content': {'event': 'mouse_move', 'x': 106.37638617090671, 'y': 220.2872170285733}}}, 'buffers': []})
# DEBUG:Comm:handle_msg[d4cf2278f4c740299a7abc968a8aeba2]({'header': {'date': datetime.datetime(2025, 1, 5, 12, 24, 27, 218000, tzinfo=tzutc()), 'msg_id': '3e2481e8-ad15-41db-a3ae-01edfe62a91a', 'msg_type': 'comm_msg', 'session': 'f8fd1fda-52da-45aa-b2e6-90a7650f0e3a', 'username': '4c80f49d-0a5b-4b83-a405-c265b0e97cf0', 'version': '5.2'}, 'msg_id': '3e2481e8-ad15-41db-a3ae-01edfe62a91a', 'msg_type': 'comm_msg', 'parent_header': {}, 'metadata': {}, 'content': {'comm_id': 'd4cf2278f4c740299a7abc968a8aeba2', 'data': {'method': 'custom', 'content': {'event': 'mouse_move', 'x': 107.63209393346379, 'y': 220.10783004402236}}}, 'buffers': []})
# DEBUG:Comm:handle_msg[d4cf2278f4c740299a7abc968a8aeba2]({'header': {'date': datetime.datetime(2025, 1, 5, 12, 24, 27, 227000, tzinfo=tzutc()), 'msg_id': 'f8db6ec7-8b72-4319-b6d5-1c0030285d5e', 'msg_type': 'comm_msg', 'session': 'f8fd1fda-52da-45aa-b2e6-90a7650f0e3a', 'username': '4c80f49d-0a5b-4b83-a405-c265b0e97cf0', 'version': '5.2'}, 'msg_id': 'f8db6ec7-8b72-4319-b6d5-1c0030285d5e', 'msg_type': 'comm_msg', 'parent_header': {}, 'metadata': {}, 'content': {'comm_id': 'd4cf2278f4c740299a7abc968a8aeba2', 'data': {'method': 'custom', 'content': {'event': 'mouse_move', 'x': 108.34964122635355, 'y': 219.9284430594714}}}, 'buffers': []})
# DEBUG:Comm:handle_msg[d4cf2278f4c740299a7abc968a8aeba2]({'header': {'date': datetime.datetime(2025, 1, 5, 12, 24, 27, 235000, tzinfo=tzutc()), 'msg_id': '8ac93e4e-324e-49fe-a62d-56e1c7d8b00f', 'msg_type': 'comm_msg', 'session': 'f8fd1fda-52da-45aa-b2e6-90a7650f0e3a', 'username': '4c80f49d-0a5b-4b83-a405-c265b0e97cf0', 'version': '5.2'}, 'msg_id': '8ac93e4e-324e-49fe-a62d-56e1c7d8b00f', 'msg_type': 'comm_msg', 'parent_header': {}, 'metadata': {}, 'content': {'comm_id': 'd4cf2278f4c740299a7abc968a8aeba2', 'data': {'method': 'custom', 'content': {'event': 'mouse_move', 'x': 110.14350945857795, 'y': 219.5696690903695}}}, 'buffers': []})
# DEBUG:Comm:handle_msg[d4cf2278f4c740299a7abc968a8aeba2]({'header': {'date': datetime.datetime(2025, 1, 5, 12, 24, 27, 243000, tzinfo=tzutc()), 'msg_id': '80b4a497-2521-40df-9197-ead08168cdfc', 'msg_type': 'comm_msg', 'session': 'f8fd1fda-52da-45aa-b2e6-90a7650f0e3a', 'username': '4c80f49d-0a5b-4b83-a405-c265b0e97cf0', 'version': '5.2'}, 'msg_id': '80b4a497-2521-40df-9197-ead08168cdfc', 'msg_type': 'comm_msg', 'parent_header': {}, 'metadata': {}, 'content': {'comm_id': 'd4cf2278f4c740299a7abc968a8aeba2', 'data': {'method': 'custom', 'content': {'event': 'mouse_move', 'x': 110.86105675146771, 'y': 219.39028210581853}}}, 'buffers': []})
# DEBUG:Comm:handle_msg[d4cf2278f4c740299a7abc968a8aeba2]({'header': {'date': datetime.datetime(2025, 1, 5, 12, 24, 27, 252000, tzinfo=tzutc()), 'msg_id': 'a5307c9e-2d50-4dcc-bfd1-a9c5c6e908c8', 'msg_type': 'comm_msg', 'session': 'f8fd1fda-52da-45aa-b2e6-90a7650f0e3a', 'username': '4c80f49d-0a5b-4b83-a405-c265b0e97cf0', 'version': '5.2'}, 'msg_id': 'a5307c9e-2d50-4dcc-bfd1-a9c5c6e908c8', 'msg_type': 'comm_msg', 'parent_header': {}, 'metadata': {}, 'content': {'comm_id': 'd4cf2278f4c740299a7abc968a8aeba2', 'data': {'method': 'custom', 'content': {'event': 'mouse_move', 'x': 111.93737769080235, 'y': 219.39028210581853}}}, 'buffers': []})
# DEBUG:Comm:handle_msg[d4cf2278f4c740299a7abc968a8aeba2]({'header': {'date': datetime.datetime(2025, 1, 5, 12, 24, 27, 260000, tzinfo=tzutc()), 'msg_id': '4b0c8c05-8270-4d1d-8138-a2d760cf4db8', 'msg_type': 'comm_msg', 'session': 'f8fd1fda-52da-45aa-b2e6-90a7650f0e3a', 'username': '4c80f49d-0a5b-4b83-a405-c265b0e97cf0', 'version': '5.2'}, 'msg_id': '4b0c8c05-8270-4d1d-8138-a2d760cf4db8', 'msg_type': 'comm_msg', 'parent_header': {}, 'metadata': {}, 'content': {'comm_id': 'd4cf2278f4c740299a7abc968a8aeba2', 'data': {'method': 'custom', 'content': {'event': 'mouse_move', 'x': 113.01369863013699, 'y': 219.21089512126758}}}, 'buffers': []})
# DEBUG:Comm:handle_msg[d4cf2278f4c740299a7abc968a8aeba2]({'header': {'date': datetime.datetime(2025, 1, 5, 12, 24, 27, 269000, tzinfo=tzutc()), 'msg_id': '8b28fa4e-3586-43b9-8d54-ed522a88e4c1', 'msg_type': 'comm_msg', 'session': 'f8fd1fda-52da-45aa-b2e6-90a7650f0e3a', 'username': '4c80f49d-0a5b-4b83-a405-c265b0e97cf0', 'version': '5.2'}, 'msg_id': '8b28fa4e-3586-43b9-8d54-ed522a88e4c1', 'msg_type': 'comm_msg', 'parent_header': {}, 'metadata': {}, 'content': {'comm_id': 'd4cf2278f4c740299a7abc968a8aeba2', 'data': {'method': 'custom', 'content': {'event': 'mouse_move', 'x': 114.80756686236138, 'y': 219.03150813671664}}}, 'buffers': []})
# DEBUG:Comm:handle_msg[d4cf2278f4c740299a7abc968a8aeba2]({'header': {'date': datetime.datetime(2025, 1, 5, 12, 24, 27, 277000, tzinfo=tzutc()), 'msg_id': '8f8c8d58-f72d-48fc-8dd5-75009bda9625', 'msg_type': 'comm_msg', 'session': 'f8fd1fda-52da-45aa-b2e6-90a7650f0e3a', 'username': '4c80f49d-0a5b-4b83-a405-c265b0e97cf0', 'version': '5.2'}, 'msg_id': '8f8c8d58-f72d-48fc-8dd5-75009bda9625', 'msg_type': 'comm_msg', 'parent_header': {}, 'metadata': {}, 'content': {'comm_id': 'd4cf2278f4c740299a7abc968a8aeba2', 'data': {'method': 'custom', 'content': {'event': 'mouse_move', 'x': 116.06327462491846, 'y': 218.85212115216567}}}, 'buffers': []})
# DEBUG:Comm:handle_msg[d4cf2278f4c740299a7abc968a8aeba2]({'header': {'date': datetime.datetime(2025, 1, 5, 12, 24, 27, 286000, tzinfo=tzutc()), 'msg_id': '0a18d52b-5fad-460f-96f5-57c145528aba', 'msg_type': 'comm_msg', 'session': 'f8fd1fda-52da-45aa-b2e6-90a7650f0e3a', 'username': '4c80f49d-0a5b-4b83-a405-c265b0e97cf0', 'version': '5.2'}, 'msg_id': '0a18d52b-5fad-460f-96f5-57c145528aba', 'msg_type': 'comm_msg', 'parent_header': {}, 'metadata': {}, 'content': {'comm_id': 'd4cf2278f4c740299a7abc968a8aeba2', 'data': {'method': 'custom', 'content': {'event': 'mouse_wheel', 'x': 0, 'y': 100}}}, 'buffers': []})
# DEBUG:Comm:handle_msg[d4cf2278f4c740299a7abc968a8aeba2]({'header': {'date': datetime.datetime(2025, 1, 5, 12, 24, 27, 286000, tzinfo=tzutc()), 'msg_id': 'b77f2702-7b85-4d93-a2bb-a648fe19fffe', 'msg_type': 'comm_msg', 'session': 'f8fd1fda-52da-45aa-b2e6-90a7650f0e3a', 'username': '4c80f49d-0a5b-4b83-a405-c265b0e97cf0', 'version': '5.2'}, 'msg_id': 'b77f2702-7b85-4d93-a2bb-a648fe19fffe', 'msg_type': 'comm_msg', 'parent_header': {}, 'metadata': {}, 'content': {'comm_id': 'd4cf2278f4c740299a7abc968a8aeba2', 'data': {'method': 'custom', 'content': {'event': 'mouse_move', 'x': 118.21591650358774, 'y': 218.49334718306375}}}, 'buffers': []})
# DEBUG:Comm:handle_msg[d4cf2278f4c740299a7abc968a8aeba2]({'header': {'date': datetime.datetime(2025, 1, 5, 12, 24, 27, 293000, tzinfo=tzutc()), 'msg_id': 'ddef0129-7398-4a67-a121-e04767ae5e00', 'msg_type': 'comm_msg', 'session': 'f8fd1fda-52da-45aa-b2e6-90a7650f0e3a', 'username': '4c80f49d-0a5b-4b83-a405-c265b0e97cf0', 'version': '5.2'}, 'msg_id': 'ddef0129-7398-4a67-a121-e04767ae5e00', 'msg_type': 'comm_msg', 'parent_header': {}, 'metadata': {}, 'content': {'comm_id': 'd4cf2278f4c740299a7abc968a8aeba2', 'data': {'method': 'custom', 'content': {'event': 'mouse_move', 'x': 119.47162426614481, 'y': 218.49334718306375}}}, 'buffers': []})
# DEBUG:Comm:handle_msg[d4cf2278f4c740299a7abc968a8aeba2]({'header': {'date': datetime.datetime(2025, 1, 5, 12, 24, 27, 310000, tzinfo=tzutc()), 'msg_id': 'e95412ce-c24d-4cc2-84a9-c0be1d7f2467', 'msg_type': 'comm_msg', 'session': 'f8fd1fda-52da-45aa-b2e6-90a7650f0e3a', 'username': '4c80f49d-0a5b-4b83-a405-c265b0e97cf0', 'version': '5.2'}, 'msg_id': 'e95412ce-c24d-4cc2-84a9-c0be1d7f2467', 'msg_type': 'comm_msg', 'parent_header': {}, 'metadata': {}, 'content': {'comm_id': 'd4cf2278f4c740299a7abc968a8aeba2', 'data': {'method': 'custom', 'content': {'event': 'mouse_move', 'x': 121.80365296803653, 'y': 218.13457321396186}}}, 'buffers': []})
# DEBUG:Comm:handle_msg[d4cf2278f4c740299a7abc968a8aeba2]({'header': {'date': datetime.datetime(2025, 1, 5, 12, 24, 27, 319000, tzinfo=tzutc()), 'msg_id': '13340349-0578-4b83-96c0-5bcde5638cff', 'msg_type': 'comm_msg', 'session': 'f8fd1fda-52da-45aa-b2e6-90a7650f0e3a', 'username': '4c80f49d-0a5b-4b83-a405-c265b0e97cf0', 'version': '5.2'}, 'msg_id': '13340349-0578-4b83-96c0-5bcde5638cff', 'msg_type': 'comm_msg', 'parent_header': {}, 'metadata': {}, 'content': {'comm_id': 'd4cf2278f4c740299a7abc968a8aeba2', 'data': {'method': 'custom', 'content': {'event': 'mouse_move', 'x': 122.70058708414872, 'y': 217.95518622941088}}}, 'buffers': []})
# DEBUG:Comm:handle_msg[d4cf2278f4c740299a7abc968a8aeba2]({'header': {'date': datetime.datetime(2025, 1, 5, 12, 24, 27, 328000, tzinfo=tzutc()), 'msg_id': 'cded4d48-4618-405d-95a7-5ad580fa51f4', 'msg_type': 'comm_msg', 'session': 'f8fd1fda-52da-45aa-b2e6-90a7650f0e3a', 'username': '4c80f49d-0a5b-4b83-a405-c265b0e97cf0', 'version': '5.2'}, 'msg_id': 'cded4d48-4618-405d-95a7-5ad580fa51f4', 'msg_type': 'comm_msg', 'parent_header': {}, 'metadata': {}, 'content': {'comm_id': 'd4cf2278f4c740299a7abc968a8aeba2', 'data': {'method': 'custom', 'content': {'event': 'mouse_move', 'x': 123.41813437703848, 'y': 217.95518622941088}}}, 'buffers': []})
# DEBUG:Comm:handle_msg[d4cf2278f4c740299a7abc968a8aeba2]({'header': {'date': datetime.datetime(2025, 1, 5, 12, 24, 27, 343000, tzinfo=tzutc()), 'msg_id': 'ffdf4c85-5bf7-45aa-8f2e-b104fb951b75', 'msg_type': 'comm_msg', 'session': 'f8fd1fda-52da-45aa-b2e6-90a7650f0e3a', 'username': '4c80f49d-0a5b-4b83-a405-c265b0e97cf0', 'version': '5.2'}, 'msg_id': 'ffdf4c85-5bf7-45aa-8f2e-b104fb951b75', 'msg_type': 'comm_msg', 'parent_header': {}, 'metadata': {}, 'content': {'comm_id': 'd4cf2278f4c740299a7abc968a8aeba2', 'data': {'method': 'custom', 'content': {'event': 'mouse_move', 'x': 124.49445531637312, 'y': 217.77579924485994}}}, 'buffers': []})
# DEBUG:Comm:handle_msg[d4cf2278f4c740299a7abc968a8aeba2]({'header': {'date': datetime.datetime(2025, 1, 5, 12, 24, 27, 353000, tzinfo=tzutc()), 'msg_id': '9e45e2ae-37d3-49b6-8da6-cd2dbbfa60e1', 'msg_type': 'comm_msg', 'session': 'f8fd1fda-52da-45aa-b2e6-90a7650f0e3a', 'username': '4c80f49d-0a5b-4b83-a405-c265b0e97cf0', 'version': '5.2'}, 'msg_id': '9e45e2ae-37d3-49b6-8da6-cd2dbbfa60e1', 'msg_type': 'comm_msg', 'parent_header': {}, 'metadata': {}, 'content': {'comm_id': 'd4cf2278f4c740299a7abc968a8aeba2', 'data': {'method': 'custom', 'content': {'event': 'mouse_move', 'x': 125.03261578604044, 'y': 217.77579924485994}}}, 'buffers': []})
# DEBUG:Comm:handle_msg[d4cf2278f4c740299a7abc968a8aeba2]({'header': {'date': datetime.datetime(2025, 1, 5, 12, 24, 27, 361000, tzinfo=tzutc()), 'msg_id': '5ebeb1a3-aa8d-4915-8e79-47e67de112c1', 'msg_type': 'comm_msg', 'session': 'f8fd1fda-52da-45aa-b2e6-90a7650f0e3a', 'username': '4c80f49d-0a5b-4b83-a405-c265b0e97cf0', 'version': '5.2'}, 'msg_id': '5ebeb1a3-aa8d-4915-8e79-47e67de112c1', 'msg_type': 'comm_msg', 'parent_header': {}, 'metadata': {}, 'content': {'comm_id': 'd4cf2278f4c740299a7abc968a8aeba2', 'data': {'method': 'custom', 'content': {'event': 'mouse_move', 'x': 125.7501630789302, 'y': 217.77579924485994}}}, 'buffers': []})
# DEBUG:Comm:handle_msg[d4cf2278f4c740299a7abc968a8aeba2]({'header': {'date': datetime.datetime(2025, 1, 5, 12, 24, 27, 377000, tzinfo=tzutc()), 'msg_id': 'b8dfad8e-8a94-48ad-b2e6-8f5c1a3d1387', 'msg_type': 'comm_msg', 'session': 'f8fd1fda-52da-45aa-b2e6-90a7650f0e3a', 'username': '4c80f49d-0a5b-4b83-a405-c265b0e97cf0', 'version': '5.2'}, 'msg_id': 'b8dfad8e-8a94-48ad-b2e6-8f5c1a3d1387', 'msg_type': 'comm_msg', 'parent_header': {}, 'metadata': {}, 'content': {'comm_id': 'd4cf2278f4c740299a7abc968a8aeba2', 'data': {'method': 'custom', 'content': {'event': 'mouse_move', 'x': 126.82648401826484, 'y': 217.77579924485994}}}, 'buffers': []})
# DEBUG:Comm:handle_msg[d4cf2278f4c740299a7abc968a8aeba2]({'header': {'date': datetime.datetime(2025, 1, 5, 12, 24, 27, 385000, tzinfo=tzutc()), 'msg_id': 'cff89a1b-c0ba-40c7-a3a1-3b72472156ad', 'msg_type': 'comm_msg', 'session': 'f8fd1fda-52da-45aa-b2e6-90a7650f0e3a', 'username': '4c80f49d-0a5b-4b83-a405-c265b0e97cf0', 'version': '5.2'}, 'msg_id': 'cff89a1b-c0ba-40c7-a3a1-3b72472156ad', 'msg_type': 'comm_msg', 'parent_header': {}, 'metadata': {}, 'content': {'comm_id': 'd4cf2278f4c740299a7abc968a8aeba2', 'data': {'method': 'custom', 'content': {'event': 'mouse_move', 'x': 127.00587084148728, 'y': 217.77579924485994}}}, 'buffers': []})
# DEBUG:Comm:handle_msg[d4cf2278f4c740299a7abc968a8aeba2]({'header': {'date': datetime.datetime(2025, 1, 5, 12, 24, 27, 385000, tzinfo=tzutc()), 'msg_id': '6cdbb61b-8492-4186-ba14-3e74789f3099', 'msg_type': 'comm_msg', 'session': 'f8fd1fda-52da-45aa-b2e6-90a7650f0e3a', 'username': '4c80f49d-0a5b-4b83-a405-c265b0e97cf0', 'version': '5.2'}, 'msg_id': '6cdbb61b-8492-4186-ba14-3e74789f3099', 'msg_type': 'comm_msg', 'parent_header': {}, 'metadata': {}, 'content': {'comm_id': 'd4cf2278f4c740299a7abc968a8aeba2', 'data': {'method': 'custom', 'content': {'event': 'mouse_wheel', 'x': 0, 'y': -100}}}, 'buffers': []})
# DEBUG:Comm:handle_msg[d4cf2278f4c740299a7abc968a8aeba2]({'header': {'date': datetime.datetime(2025, 1, 5, 12, 24, 27, 394000, tzinfo=tzutc()), 'msg_id': '6b760846-48ef-4aa8-be01-5b01198df339', 'msg_type': 'comm_msg', 'session': 'f8fd1fda-52da-45aa-b2e6-90a7650f0e3a', 'username': '4c80f49d-0a5b-4b83-a405-c265b0e97cf0', 'version': '5.2'}, 'msg_id': '6b760846-48ef-4aa8-be01-5b01198df339', 'msg_type': 'comm_msg', 'parent_header': {}, 'metadata': {}, 'content': {'comm_id': 'd4cf2278f4c740299a7abc968a8aeba2', 'data': {'method': 'custom', 'content': {'event': 'mouse_move', 'x': 127.36464448793215, 'y': 217.77579924485994}}}, 'buffers': []})
# DEBUG:Comm:handle_msg[d4cf2278f4c740299a7abc968a8aeba2]({'header': {'date': datetime.datetime(2025, 1, 5, 12, 24, 27, 403000, tzinfo=tzutc()), 'msg_id': 'c28b0aed-63a2-48b6-a14c-cc2ab9c2e4f9', 'msg_type': 'comm_msg', 'session': 'f8fd1fda-52da-45aa-b2e6-90a7650f0e3a', 'username': '4c80f49d-0a5b-4b83-a405-c265b0e97cf0', 'version': '5.2'}, 'msg_id': 'c28b0aed-63a2-48b6-a14c-cc2ab9c2e4f9', 'msg_type': 'comm_msg', 'parent_header': {}, 'metadata': {}, 'content': {'comm_id': 'd4cf2278f4c740299a7abc968a8aeba2', 'data': {'method': 'custom', 'content': {'event': 'mouse_move', 'x': 127.72341813437704, 'y': 217.77579924485994}}}, 'buffers': []})
# DEBUG:Comm:handle_msg[d4cf2278f4c740299a7abc968a8aeba2]({'header': {'date': datetime.datetime(2025, 1, 5, 12, 24, 27, 410000, tzinfo=tzutc()), 'msg_id': 'e8a04e52-4c2e-4e89-8996-bd42e7c00610', 'msg_type': 'comm_msg', 'session': 'f8fd1fda-52da-45aa-b2e6-90a7650f0e3a', 'username': '4c80f49d-0a5b-4b83-a405-c265b0e97cf0', 'version': '5.2'}, 'msg_id': 'e8a04e52-4c2e-4e89-8996-bd42e7c00610', 'msg_type': 'comm_msg', 'parent_header': {}, 'metadata': {}, 'content': {'comm_id': 'd4cf2278f4c740299a7abc968a8aeba2', 'data': {'method': 'custom', 'content': {'event': 'mouse_move', 'x': 127.90280495759947, 'y': 217.77579924485994}}}, 'buffers': []})
# DEBUG:Comm:handle_msg[d4cf2278f4c740299a7abc968a8aeba2]({'header': {'date': datetime.datetime(2025, 1, 5, 12, 24, 27, 418000, tzinfo=tzutc()), 'msg_id': '089f58e9-ef7a-4f7e-9887-0021d1ba03ab', 'msg_type': 'comm_msg', 'session': 'f8fd1fda-52da-45aa-b2e6-90a7650f0e3a', 'username': '4c80f49d-0a5b-4b83-a405-c265b0e97cf0', 'version': '5.2'}, 'msg_id': '089f58e9-ef7a-4f7e-9887-0021d1ba03ab', 'msg_type': 'comm_msg', 'parent_header': {}, 'metadata': {}, 'content': {'comm_id': 'd4cf2278f4c740299a7abc968a8aeba2', 'data': {'method': 'custom', 'content': {'event': 'mouse_move', 'x': 128.26157860404436, 'y': 217.77579924485994}}}, 'buffers': []})
# DEBUG:Comm:handle_msg[d4cf2278f4c740299a7abc968a8aeba2]({'header': {'date': datetime.datetime(2025, 1, 5, 12, 24, 27, 427000, tzinfo=tzutc()), 'msg_id': '28e26ac3-38bc-45fe-b3cf-e12b0c767bbf', 'msg_type': 'comm_msg', 'session': 'f8fd1fda-52da-45aa-b2e6-90a7650f0e3a', 'username': '4c80f49d-0a5b-4b83-a405-c265b0e97cf0', 'version': '5.2'}, 'msg_id': '28e26ac3-38bc-45fe-b3cf-e12b0c767bbf', 'msg_type': 'comm_msg', 'parent_header': {}, 'metadata': {}, 'content': {'comm_id': 'd4cf2278f4c740299a7abc968a8aeba2', 'data': {'method': 'custom', 'content': {'event': 'mouse_move', 'x': 128.4409654272668, 'y': 217.77579924485994}}}, 'buffers': []})
# DEBUG:Comm:handle_msg[d4cf2278f4c740299a7abc968a8aeba2]({'header': {'date': datetime.datetime(2025, 1, 5, 12, 24, 27, 435000, tzinfo=tzutc()), 'msg_id': 'fd147b21-d20f-4367-b5b0-2271cf258801', 'msg_type': 'comm_msg', 'session': 'f8fd1fda-52da-45aa-b2e6-90a7650f0e3a', 'username': '4c80f49d-0a5b-4b83-a405-c265b0e97cf0', 'version': '5.2'}, 'msg_id': 'fd147b21-d20f-4367-b5b0-2271cf258801', 'msg_type': 'comm_msg', 'parent_header': {}, 'metadata': {}, 'content': {'comm_id': 'd4cf2278f4c740299a7abc968a8aeba2', 'data': {'method': 'custom', 'content': {'event': 'mouse_wheel', 'x': 0, 'y': -100}}}, 'buffers': []})
# DEBUG:Comm:handle_msg[d4cf2278f4c740299a7abc968a8aeba2]({'header': {'date': datetime.datetime(2025, 1, 5, 12, 24, 27, 435000, tzinfo=tzutc()), 'msg_id': '4e37fa8d-c3f9-4478-8387-ecca64819795', 'msg_type': 'comm_msg', 'session': 'f8fd1fda-52da-45aa-b2e6-90a7650f0e3a', 'username': '4c80f49d-0a5b-4b83-a405-c265b0e97cf0', 'version': '5.2'}, 'msg_id': '4e37fa8d-c3f9-4478-8387-ecca64819795', 'msg_type': 'comm_msg', 'parent_header': {}, 'metadata': {}, 'content': {'comm_id': 'd4cf2278f4c740299a7abc968a8aeba2', 'data': {'method': 'custom', 'content': {'event': 'mouse_move', 'x': 129.15851272015655, 'y': 217.77579924485994}}}, 'buffers': []})
# DEBUG:Comm:handle_msg[d4cf2278f4c740299a7abc968a8aeba2]({'header': {'date': datetime.datetime(2025, 1, 5, 12, 24, 27, 445000, tzinfo=tzutc()), 'msg_id': '17c39b80-60f0-4f22-8f9a-1fad51aeb0b3', 'msg_type': 'comm_msg', 'session': 'f8fd1fda-52da-45aa-b2e6-90a7650f0e3a', 'username': '4c80f49d-0a5b-4b83-a405-c265b0e97cf0', 'version': '5.2'}, 'msg_id': '17c39b80-60f0-4f22-8f9a-1fad51aeb0b3', 'msg_type': 'comm_msg', 'parent_header': {}, 'metadata': {}, 'content': {'comm_id': 'd4cf2278f4c740299a7abc968a8aeba2', 'data': {'method': 'custom', 'content': {'event': 'mouse_move', 'x': 129.51728636660144, 'y': 217.77579924485994}}}, 'buffers': []})
# DEBUG:Comm:handle_msg[d4cf2278f4c740299a7abc968a8aeba2]({'header': {'date': datetime.datetime(2025, 1, 5, 12, 24, 27, 452000, tzinfo=tzutc()), 'msg_id': '59d59f27-f8b4-4e95-90a4-0127002ee346', 'msg_type': 'comm_msg', 'session': 'f8fd1fda-52da-45aa-b2e6-90a7650f0e3a', 'username': '4c80f49d-0a5b-4b83-a405-c265b0e97cf0', 'version': '5.2'}, 'msg_id': '59d59f27-f8b4-4e95-90a4-0127002ee346', 'msg_type': 'comm_msg', 'parent_header': {}, 'metadata': {}, 'content': {'comm_id': 'd4cf2278f4c740299a7abc968a8aeba2', 'data': {'method': 'custom', 'content': {'event': 'mouse_move', 'x': 129.69667318982388, 'y': 217.77579924485994}}}, 'buffers': []})
# DEBUG:Comm:handle_msg[d4cf2278f4c740299a7abc968a8aeba2]({'header': {'date': datetime.datetime(2025, 1, 5, 12, 24, 27, 460000, tzinfo=tzutc()), 'msg_id': 'd73b6e0f-96dd-4e48-902d-c7a78a9600bb', 'msg_type': 'comm_msg', 'session': 'f8fd1fda-52da-45aa-b2e6-90a7650f0e3a', 'username': '4c80f49d-0a5b-4b83-a405-c265b0e97cf0', 'version': '5.2'}, 'msg_id': 'd73b6e0f-96dd-4e48-902d-c7a78a9600bb', 'msg_type': 'comm_msg', 'parent_header': {}, 'metadata': {}, 'content': {'comm_id': 'd4cf2278f4c740299a7abc968a8aeba2', 'data': {'method': 'custom', 'content': {'event': 'mouse_move', 'x': 129.87606001304633, 'y': 217.77579924485994}}}, 'buffers': []})
# DEBUG:Comm:handle_msg[d4cf2278f4c740299a7abc968a8aeba2]({'header': {'date': datetime.datetime(2025, 1, 5, 12, 24, 27, 468000, tzinfo=tzutc()), 'msg_id': '15ee70c8-10e6-4ad2-af23-032c6addcfbc', 'msg_type': 'comm_msg', 'session': 'f8fd1fda-52da-45aa-b2e6-90a7650f0e3a', 'username': '4c80f49d-0a5b-4b83-a405-c265b0e97cf0', 'version': '5.2'}, 'msg_id': '15ee70c8-10e6-4ad2-af23-032c6addcfbc', 'msg_type': 'comm_msg', 'parent_header': {}, 'metadata': {}, 'content': {'comm_id': 'd4cf2278f4c740299a7abc968a8aeba2', 'data': {'method': 'custom', 'content': {'event': 'mouse_move', 'x': 130.05544683626874, 'y': 217.77579924485994}}}, 'buffers': []})
# DEBUG:Comm:handle_msg[d4cf2278f4c740299a7abc968a8aeba2]({'header': {'date': datetime.datetime(2025, 1, 5, 12, 24, 27, 476000, tzinfo=tzutc()), 'msg_id': '98328e60-73e5-484e-a324-f3849ac32f4b', 'msg_type': 'comm_msg', 'session': 'f8fd1fda-52da-45aa-b2e6-90a7650f0e3a', 'username': '4c80f49d-0a5b-4b83-a405-c265b0e97cf0', 'version': '5.2'}, 'msg_id': '98328e60-73e5-484e-a324-f3849ac32f4b', 'msg_type': 'comm_msg', 'parent_header': {}, 'metadata': {}, 'content': {'comm_id': 'd4cf2278f4c740299a7abc968a8aeba2', 'data': {'method': 'custom', 'content': {'event': 'mouse_move', 'x': 130.2348336594912, 'y': 217.77579924485994}}}, 'buffers': []})
# DEBUG:Comm:handle_msg[d4cf2278f4c740299a7abc968a8aeba2]({'header': {'date': datetime.datetime(2025, 1, 5, 12, 24, 27, 485000, tzinfo=tzutc()), 'msg_id': 'fbbe9e25-0d8a-4694-a065-b4c1f560e5d6', 'msg_type': 'comm_msg', 'session': 'f8fd1fda-52da-45aa-b2e6-90a7650f0e3a', 'username': '4c80f49d-0a5b-4b83-a405-c265b0e97cf0', 'version': '5.2'}, 'msg_id': 'fbbe9e25-0d8a-4694-a065-b4c1f560e5d6', 'msg_type': 'comm_msg', 'parent_header': {}, 'metadata': {}, 'content': {'comm_id': 'd4cf2278f4c740299a7abc968a8aeba2', 'data': {'method': 'custom', 'content': {'event': 'mouse_wheel', 'x': 0, 'y': -100}}}, 'buffers': []})
# DEBUG:Comm:handle_msg[d4cf2278f4c740299a7abc968a8aeba2]({'header': {'date': datetime.datetime(2025, 1, 5, 12, 24, 27, 485000, tzinfo=tzutc()), 'msg_id': 'ac1aec4f-80d3-49cb-878a-81c931f2a5b7', 'msg_type': 'comm_msg', 'session': 'f8fd1fda-52da-45aa-b2e6-90a7650f0e3a', 'username': '4c80f49d-0a5b-4b83-a405-c265b0e97cf0', 'version': '5.2'}, 'msg_id': 'ac1aec4f-80d3-49cb-878a-81c931f2a5b7', 'msg_type': 'comm_msg', 'parent_header': {}, 'metadata': {}, 'content': {'comm_id': 'd4cf2278f4c740299a7abc968a8aeba2', 'data': {'method': 'custom', 'content': {'event': 'mouse_move', 'x': 130.41422048271363, 'y': 217.77579924485994}}}, 'buffers': []})
# DEBUG:Comm:handle_msg[d4cf2278f4c740299a7abc968a8aeba2]({'header': {'date': datetime.datetime(2025, 1, 5, 12, 24, 27, 493000, tzinfo=tzutc()), 'msg_id': '781d8442-2db7-4f18-807a-0cb9be988689', 'msg_type': 'comm_msg', 'session': 'f8fd1fda-52da-45aa-b2e6-90a7650f0e3a', 'username': '4c80f49d-0a5b-4b83-a405-c265b0e97cf0', 'version': '5.2'}, 'msg_id': '781d8442-2db7-4f18-807a-0cb9be988689', 'msg_type': 'comm_msg', 'parent_header': {}, 'metadata': {}, 'content': {'comm_id': 'd4cf2278f4c740299a7abc968a8aeba2', 'data': {'method': 'custom', 'content': {'event': 'mouse_move', 'x': 130.59360730593608, 'y': 217.77579924485994}}}, 'buffers': []})
# DEBUG:Comm:handle_msg[d4cf2278f4c740299a7abc968a8aeba2]({'header': {'date': datetime.datetime(2025, 1, 5, 12, 24, 27, 502000, tzinfo=tzutc()), 'msg_id': '7efd905f-642e-4220-b0f8-0daa1b332c3a', 'msg_type': 'comm_msg', 'session': 'f8fd1fda-52da-45aa-b2e6-90a7650f0e3a', 'username': '4c80f49d-0a5b-4b83-a405-c265b0e97cf0', 'version': '5.2'}, 'msg_id': '7efd905f-642e-4220-b0f8-0daa1b332c3a', 'msg_type': 'comm_msg', 'parent_header': {}, 'metadata': {}, 'content': {'comm_id': 'd4cf2278f4c740299a7abc968a8aeba2', 'data': {'method': 'custom', 'content': {'event': 'mouse_move', 'x': 131.31115459882582, 'y': 217.77579924485994}}}, 'buffers': []})
# DEBUG:Comm:handle_msg[d4cf2278f4c740299a7abc968a8aeba2]({'header': {'date': datetime.datetime(2025, 1, 5, 12, 24, 27, 510000, tzinfo=tzutc()), 'msg_id': '0e2f5974-952c-4579-ad06-6bc737e4a601', 'msg_type': 'comm_msg', 'session': 'f8fd1fda-52da-45aa-b2e6-90a7650f0e3a', 'username': '4c80f49d-0a5b-4b83-a405-c265b0e97cf0', 'version': '5.2'}, 'msg_id': '0e2f5974-952c-4579-ad06-6bc737e4a601', 'msg_type': 'comm_msg', 'parent_header': {}, 'metadata': {}, 'content': {'comm_id': 'd4cf2278f4c740299a7abc968a8aeba2', 'data': {'method': 'custom', 'content': {'event': 'mouse_move', 'x': 132.0287018917156, 'y': 217.77579924485994}}}, 'buffers': []})
# DEBUG:Comm:handle_msg[d4cf2278f4c740299a7abc968a8aeba2]({'header': {'date': datetime.datetime(2025, 1, 5, 12, 24, 27, 520000, tzinfo=tzutc()), 'msg_id': '7b3121c5-d582-4777-8435-13ad704eac5f', 'msg_type': 'comm_msg', 'session': 'f8fd1fda-52da-45aa-b2e6-90a7650f0e3a', 'username': '4c80f49d-0a5b-4b83-a405-c265b0e97cf0', 'version': '5.2'}, 'msg_id': '7b3121c5-d582-4777-8435-13ad704eac5f', 'msg_type': 'comm_msg', 'parent_header': {}, 'metadata': {}, 'content': {'comm_id': 'd4cf2278f4c740299a7abc968a8aeba2', 'data': {'method': 'custom', 'content': {'event': 'mouse_move', 'x': 133.4637964774951, 'y': 217.77579924485994}}}, 'buffers': []})
# DEBUG:Comm:handle_msg[d4cf2278f4c740299a7abc968a8aeba2]({'header': {'date': datetime.datetime(2025, 1, 5, 12, 24, 27, 527000, tzinfo=tzutc()), 'msg_id': '8d0ec1ee-25ef-41a3-a6da-05b43219b260', 'msg_type': 'comm_msg', 'session': 'f8fd1fda-52da-45aa-b2e6-90a7650f0e3a', 'username': '4c80f49d-0a5b-4b83-a405-c265b0e97cf0', 'version': '5.2'}, 'msg_id': '8d0ec1ee-25ef-41a3-a6da-05b43219b260', 'msg_type': 'comm_msg', 'parent_header': {}, 'metadata': {}, 'content': {'comm_id': 'd4cf2278f4c740299a7abc968a8aeba2', 'data': {'method': 'custom', 'content': {'event': 'mouse_move', 'x': 134.71950424005217, 'y': 217.77579924485994}}}, 'buffers': []})
# DEBUG:Comm:handle_msg[d4cf2278f4c740299a7abc968a8aeba2]({'header': {'date': datetime.datetime(2025, 1, 5, 12, 24, 27, 538000, tzinfo=tzutc()), 'msg_id': '93bba95b-8238-47ac-bd04-6882019bdb44', 'msg_type': 'comm_msg', 'session': 'f8fd1fda-52da-45aa-b2e6-90a7650f0e3a', 'username': '4c80f49d-0a5b-4b83-a405-c265b0e97cf0', 'version': '5.2'}, 'msg_id': '93bba95b-8238-47ac-bd04-6882019bdb44', 'msg_type': 'comm_msg', 'parent_header': {}, 'metadata': {}, 'content': {'comm_id': 'd4cf2278f4c740299a7abc968a8aeba2', 'data': {'method': 'custom', 'content': {'event': 'mouse_move', 'x': 136.5133724722766, 'y': 217.77579924485994}}}, 'buffers': []})
# DEBUG:Comm:handle_msg[d4cf2278f4c740299a7abc968a8aeba2]({'header': {'date': datetime.datetime(2025, 1, 5, 12, 24, 27, 545000, tzinfo=tzutc()), 'msg_id': 'efff9149-1b62-4435-ba42-45cba0048241', 'msg_type': 'comm_msg', 'session': 'f8fd1fda-52da-45aa-b2e6-90a7650f0e3a', 'username': '4c80f49d-0a5b-4b83-a405-c265b0e97cf0', 'version': '5.2'}, 'msg_id': 'efff9149-1b62-4435-ba42-45cba0048241', 'msg_type': 'comm_msg', 'parent_header': {}, 'metadata': {}, 'content': {'comm_id': 'd4cf2278f4c740299a7abc968a8aeba2', 'data': {'method': 'custom', 'content': {'event': 'mouse_move', 'x': 138.30724070450097, 'y': 217.77579924485994}}}, 'buffers': []})
# DEBUG:Comm:handle_msg[d4cf2278f4c740299a7abc968a8aeba2]({'header': {'date': datetime.datetime(2025, 1, 5, 12, 24, 27, 562000, tzinfo=tzutc()), 'msg_id': 'f7ef2828-685e-4b31-8b80-b1b3edeb434f', 'msg_type': 'comm_msg', 'session': 'f8fd1fda-52da-45aa-b2e6-90a7650f0e3a', 'username': '4c80f49d-0a5b-4b83-a405-c265b0e97cf0', 'version': '5.2'}, 'msg_id': 'f7ef2828-685e-4b31-8b80-b1b3edeb434f', 'msg_type': 'comm_msg', 'parent_header': {}, 'metadata': {}, 'content': {'comm_id': 'd4cf2278f4c740299a7abc968a8aeba2', 'data': {'method': 'custom', 'content': {'event': 'mouse_move', 'x': 139.02478799739075, 'y': 217.77579924485994}}}, 'buffers': []})
# DEBUG:Comm:handle_msg[d4cf2278f4c740299a7abc968a8aeba2]({'header': {'date': datetime.datetime(2025, 1, 5, 12, 24, 27, 569000, tzinfo=tzutc()), 'msg_id': '5a7c2e25-6ec3-4060-ac22-136560e9074f', 'msg_type': 'comm_msg', 'session': 'f8fd1fda-52da-45aa-b2e6-90a7650f0e3a', 'username': '4c80f49d-0a5b-4b83-a405-c265b0e97cf0', 'version': '5.2'}, 'msg_id': '5a7c2e25-6ec3-4060-ac22-136560e9074f', 'msg_type': 'comm_msg', 'parent_header': {}, 'metadata': {}, 'content': {'comm_id': 'd4cf2278f4c740299a7abc968a8aeba2', 'data': {'method': 'custom', 'content': {'event': 'mouse_move', 'x': 140.99804305283757, 'y': 217.596412260309}}}, 'buffers': []})
# DEBUG:Comm:handle_msg[d4cf2278f4c740299a7abc968a8aeba2]({'header': {'date': datetime.datetime(2025, 1, 5, 12, 24, 27, 577000, tzinfo=tzutc()), 'msg_id': 'b93461fa-5b50-44a8-88f9-5cfbc9ac40dd', 'msg_type': 'comm_msg', 'session': 'f8fd1fda-52da-45aa-b2e6-90a7650f0e3a', 'username': '4c80f49d-0a5b-4b83-a405-c265b0e97cf0', 'version': '5.2'}, 'msg_id': 'b93461fa-5b50-44a8-88f9-5cfbc9ac40dd', 'msg_type': 'comm_msg', 'parent_header': {}, 'metadata': {}, 'content': {'comm_id': 'd4cf2278f4c740299a7abc968a8aeba2', 'data': {'method': 'custom', 'content': {'event': 'mouse_move', 'x': 143.15068493150685, 'y': 217.596412260309}}}, 'buffers': []})
# DEBUG:Comm:handle_msg[d4cf2278f4c740299a7abc968a8aeba2]({'header': {'date': datetime.datetime(2025, 1, 5, 12, 24, 27, 588000, tzinfo=tzutc()), 'msg_id': 'aa3fe339-6530-4011-856f-b1ff5f37378f', 'msg_type': 'comm_msg', 'session': 'f8fd1fda-52da-45aa-b2e6-90a7650f0e3a', 'username': '4c80f49d-0a5b-4b83-a405-c265b0e97cf0', 'version': '5.2'}, 'msg_id': 'aa3fe339-6530-4011-856f-b1ff5f37378f', 'msg_type': 'comm_msg', 'parent_header': {}, 'metadata': {}, 'content': {'comm_id': 'd4cf2278f4c740299a7abc968a8aeba2', 'data': {'method': 'custom', 'content': {'event': 'mouse_wheel', 'x': 0, 'y': -100}}}, 'buffers': []})
# DEBUG:Comm:handle_msg[d4cf2278f4c740299a7abc968a8aeba2]({'header': {'date': datetime.datetime(2025, 1, 5, 12, 24, 27, 588000, tzinfo=tzutc()), 'msg_id': '5e6fc4e4-7dde-4bae-a87a-ff270b776c0d', 'msg_type': 'comm_msg', 'session': 'f8fd1fda-52da-45aa-b2e6-90a7650f0e3a', 'username': '4c80f49d-0a5b-4b83-a405-c265b0e97cf0', 'version': '5.2'}, 'msg_id': '5e6fc4e4-7dde-4bae-a87a-ff270b776c0d', 'msg_type': 'comm_msg', 'parent_header': {}, 'metadata': {}, 'content': {'comm_id': 'd4cf2278f4c740299a7abc968a8aeba2', 'data': {'method': 'custom', 'content': {'event': 'mouse_move', 'x': 146.37964774951075, 'y': 217.41702527575802}}}, 'buffers': []})
# DEBUG:Comm:handle_msg[d4cf2278f4c740299a7abc968a8aeba2]({'header': {'date': datetime.datetime(2025, 1, 5, 12, 24, 27, 593000, tzinfo=tzutc()), 'msg_id': 'af2e94db-e9d9-481d-8db7-2da7dee9a86d', 'msg_type': 'comm_msg', 'session': 'f8fd1fda-52da-45aa-b2e6-90a7650f0e3a', 'username': '4c80f49d-0a5b-4b83-a405-c265b0e97cf0', 'version': '5.2'}, 'msg_id': 'af2e94db-e9d9-481d-8db7-2da7dee9a86d', 'msg_type': 'comm_msg', 'parent_header': {}, 'metadata': {}, 'content': {'comm_id': 'd4cf2278f4c740299a7abc968a8aeba2', 'data': {'method': 'custom', 'content': {'event': 'mouse_move', 'x': 147.27658186562297, 'y': 217.23763829120708}}}, 'buffers': []})
# DEBUG:Comm:handle_msg[d4cf2278f4c740299a7abc968a8aeba2]({'header': {'date': datetime.datetime(2025, 1, 5, 12, 24, 27, 602000, tzinfo=tzutc()), 'msg_id': '1cf732d5-8437-4323-b2ad-46c0ff192ce3', 'msg_type': 'comm_msg', 'session': 'f8fd1fda-52da-45aa-b2e6-90a7650f0e3a', 'username': '4c80f49d-0a5b-4b83-a405-c265b0e97cf0', 'version': '5.2'}, 'msg_id': '1cf732d5-8437-4323-b2ad-46c0ff192ce3', 'msg_type': 'comm_msg', 'parent_header': {}, 'metadata': {}, 'content': {'comm_id': 'd4cf2278f4c740299a7abc968a8aeba2', 'data': {'method': 'custom', 'content': {'event': 'mouse_move', 'x': 149.96738421395955, 'y': 217.0582513066561}}}, 'buffers': []})
# DEBUG:Comm:handle_msg[d4cf2278f4c740299a7abc968a8aeba2]({'header': {'date': datetime.datetime(2025, 1, 5, 12, 24, 27, 610000, tzinfo=tzutc()), 'msg_id': 'c1bbf9a9-603d-4acb-85b1-4debd306e66a', 'msg_type': 'comm_msg', 'session': 'f8fd1fda-52da-45aa-b2e6-90a7650f0e3a', 'username': '4c80f49d-0a5b-4b83-a405-c265b0e97cf0', 'version': '5.2'}, 'msg_id': 'c1bbf9a9-603d-4acb-85b1-4debd306e66a', 'msg_type': 'comm_msg', 'parent_header': {}, 'metadata': {}, 'content': {'comm_id': 'd4cf2278f4c740299a7abc968a8aeba2', 'data': {'method': 'custom', 'content': {'event': 'mouse_move', 'x': 152.8375733855186, 'y': 216.87886432210516}}}, 'buffers': []})
# DEBUG:Comm:handle_msg[d4cf2278f4c740299a7abc968a8aeba2]({'header': {'date': datetime.datetime(2025, 1, 5, 12, 24, 27, 620000, tzinfo=tzutc()), 'msg_id': '5dca6d6b-04b1-4586-8c11-cfe1f7ec2a69', 'msg_type': 'comm_msg', 'session': 'f8fd1fda-52da-45aa-b2e6-90a7650f0e3a', 'username': '4c80f49d-0a5b-4b83-a405-c265b0e97cf0', 'version': '5.2'}, 'msg_id': '5dca6d6b-04b1-4586-8c11-cfe1f7ec2a69', 'msg_type': 'comm_msg', 'parent_header': {}, 'metadata': {}, 'content': {'comm_id': 'd4cf2278f4c740299a7abc968a8aeba2', 'data': {'method': 'custom', 'content': {'event': 'mouse_move', 'x': 154.09328114807568, 'y': 216.87886432210516}}}, 'buffers': []})
# DEBUG:Comm:handle_msg[d4cf2278f4c740299a7abc968a8aeba2]({'header': {'date': datetime.datetime(2025, 1, 5, 12, 24, 27, 627000, tzinfo=tzutc()), 'msg_id': '79a0d16a-ee32-4b32-b07b-cfe6efa6c97d', 'msg_type': 'comm_msg', 'session': 'f8fd1fda-52da-45aa-b2e6-90a7650f0e3a', 'username': '4c80f49d-0a5b-4b83-a405-c265b0e97cf0', 'version': '5.2'}, 'msg_id': '79a0d16a-ee32-4b32-b07b-cfe6efa6c97d', 'msg_type': 'comm_msg', 'parent_header': {}, 'metadata': {}, 'content': {'comm_id': 'd4cf2278f4c740299a7abc968a8aeba2', 'data': {'method': 'custom', 'content': {'event': 'mouse_move', 'x': 157.50163078930203, 'y': 216.6994773375542}}}, 'buffers': []})
# DEBUG:Comm:handle_msg[d4cf2278f4c740299a7abc968a8aeba2]({'header': {'date': datetime.datetime(2025, 1, 5, 12, 24, 27, 638000, tzinfo=tzutc()), 'msg_id': '0105c227-427a-470b-b6b1-ddc21bf811f4', 'msg_type': 'comm_msg', 'session': 'f8fd1fda-52da-45aa-b2e6-90a7650f0e3a', 'username': '4c80f49d-0a5b-4b83-a405-c265b0e97cf0', 'version': '5.2'}, 'msg_id': '0105c227-427a-470b-b6b1-ddc21bf811f4', 'msg_type': 'comm_msg', 'parent_header': {}, 'metadata': {}, 'content': {'comm_id': 'd4cf2278f4c740299a7abc968a8aeba2', 'data': {'method': 'custom', 'content': {'event': 'mouse_move', 'x': 158.7573385518591, 'y': 216.52009035300324}}}, 'buffers': []})
# DEBUG:Comm:handle_msg[d4cf2278f4c740299a7abc968a8aeba2]({'header': {'date': datetime.datetime(2025, 1, 5, 12, 24, 27, 644000, tzinfo=tzutc()), 'msg_id': '8ed9707f-55eb-41a4-a642-d8fa2929949b', 'msg_type': 'comm_msg', 'session': 'f8fd1fda-52da-45aa-b2e6-90a7650f0e3a', 'username': '4c80f49d-0a5b-4b83-a405-c265b0e97cf0', 'version': '5.2'}, 'msg_id': '8ed9707f-55eb-41a4-a642-d8fa2929949b', 'msg_type': 'comm_msg', 'parent_header': {}, 'metadata': {}, 'content': {'comm_id': 'd4cf2278f4c740299a7abc968a8aeba2', 'data': {'method': 'custom', 'content': {'event': 'mouse_move', 'x': 161.986301369863, 'y': 216.3407033684523}}}, 'buffers': []})
# DEBUG:Comm:handle_msg[d4cf2278f4c740299a7abc968a8aeba2]({'header': {'date': datetime.datetime(2025, 1, 5, 12, 24, 27, 652000, tzinfo=tzutc()), 'msg_id': '65b64554-b8a8-4a2b-afc7-7241960daa45', 'msg_type': 'comm_msg', 'session': 'f8fd1fda-52da-45aa-b2e6-90a7650f0e3a', 'username': '4c80f49d-0a5b-4b83-a405-c265b0e97cf0', 'version': '5.2'}, 'msg_id': '65b64554-b8a8-4a2b-afc7-7241960daa45', 'msg_type': 'comm_msg', 'parent_header': {}, 'metadata': {}, 'content': {'comm_id': 'd4cf2278f4c740299a7abc968a8aeba2', 'data': {'method': 'custom', 'content': {'event': 'mouse_move', 'x': 163.2420091324201, 'y': 216.16131638390135}}}, 'buffers': []})
# DEBUG:Comm:handle_msg[d4cf2278f4c740299a7abc968a8aeba2]({'header': {'date': datetime.datetime(2025, 1, 5, 12, 24, 27, 661000, tzinfo=tzutc()), 'msg_id': '1089de60-b03d-430e-851e-aa480651f6c6', 'msg_type': 'comm_msg', 'session': 'f8fd1fda-52da-45aa-b2e6-90a7650f0e3a', 'username': '4c80f49d-0a5b-4b83-a405-c265b0e97cf0', 'version': '5.2'}, 'msg_id': '1089de60-b03d-430e-851e-aa480651f6c6', 'msg_type': 'comm_msg', 'parent_header': {}, 'metadata': {}, 'content': {'comm_id': 'd4cf2278f4c740299a7abc968a8aeba2', 'data': {'method': 'custom', 'content': {'event': 'mouse_move', 'x': 167.3679060665362, 'y': 215.62315543024846}}}, 'buffers': []})
# DEBUG:Comm:handle_msg[d4cf2278f4c740299a7abc968a8aeba2]({'header': {'date': datetime.datetime(2025, 1, 5, 12, 24, 27, 669000, tzinfo=tzutc()), 'msg_id': 'a77d4d16-8009-4223-adf1-9bf488a905e6', 'msg_type': 'comm_msg', 'session': 'f8fd1fda-52da-45aa-b2e6-90a7650f0e3a', 'username': '4c80f49d-0a5b-4b83-a405-c265b0e97cf0', 'version': '5.2'}, 'msg_id': 'a77d4d16-8009-4223-adf1-9bf488a905e6', 'msg_type': 'comm_msg', 'parent_header': {}, 'metadata': {}, 'content': {'comm_id': 'd4cf2278f4c740299a7abc968a8aeba2', 'data': {'method': 'custom', 'content': {'event': 'mouse_wheel', 'x': 0, 'y': -100}}}, 'buffers': []})
# DEBUG:Comm:handle_msg[d4cf2278f4c740299a7abc968a8aeba2]({'header': {'date': datetime.datetime(2025, 1, 5, 12, 24, 27, 679000, tzinfo=tzutc()), 'msg_id': '311ef18e-b730-4ba7-ae78-54810b0fd845', 'msg_type': 'comm_msg', 'session': 'f8fd1fda-52da-45aa-b2e6-90a7650f0e3a', 'username': '4c80f49d-0a5b-4b83-a405-c265b0e97cf0', 'version': '5.2'}, 'msg_id': '311ef18e-b730-4ba7-ae78-54810b0fd845', 'msg_type': 'comm_msg', 'parent_header': {}, 'metadata': {}, 'content': {'comm_id': 'd4cf2278f4c740299a7abc968a8aeba2', 'data': {'method': 'custom', 'content': {'event': 'mouse_move', 'x': 171.13502935420743, 'y': 215.26438146114657}}}, 'buffers': []})
# DEBUG:Comm:handle_msg[d4cf2278f4c740299a7abc968a8aeba2]({'header': {'date': datetime.datetime(2025, 1, 5, 12, 24, 27, 685000, tzinfo=tzutc()), 'msg_id': '4b472358-a899-482c-9a7a-d61965549102', 'msg_type': 'comm_msg', 'session': 'f8fd1fda-52da-45aa-b2e6-90a7650f0e3a', 'username': '4c80f49d-0a5b-4b83-a405-c265b0e97cf0', 'version': '5.2'}, 'msg_id': '4b472358-a899-482c-9a7a-d61965549102', 'msg_type': 'comm_msg', 'parent_header': {}, 'metadata': {}, 'content': {'comm_id': 'd4cf2278f4c740299a7abc968a8aeba2', 'data': {'method': 'custom', 'content': {'event': 'mouse_move', 'x': 171.8525766470972, 'y': 215.26438146114657}}}, 'buffers': []})
# DEBUG:Comm:handle_msg[d4cf2278f4c740299a7abc968a8aeba2]({'header': {'date': datetime.datetime(2025, 1, 5, 12, 24, 27, 693000, tzinfo=tzutc()), 'msg_id': 'e3419e75-2006-424d-a457-a0b9f8bc4fd5', 'msg_type': 'comm_msg', 'session': 'f8fd1fda-52da-45aa-b2e6-90a7650f0e3a', 'username': '4c80f49d-0a5b-4b83-a405-c265b0e97cf0', 'version': '5.2'}, 'msg_id': 'e3419e75-2006-424d-a457-a0b9f8bc4fd5', 'msg_type': 'comm_msg', 'parent_header': {}, 'metadata': {}, 'content': {'comm_id': 'd4cf2278f4c740299a7abc968a8aeba2', 'data': {'method': 'custom', 'content': {'event': 'mouse_move', 'x': 173.46705805609915, 'y': 215.26438146114657}}}, 'buffers': []})
# DEBUG:Comm:handle_msg[d4cf2278f4c740299a7abc968a8aeba2]({'header': {'date': datetime.datetime(2025, 1, 5, 12, 24, 27, 701000, tzinfo=tzutc()), 'msg_id': 'e1bd3b16-6a50-4cb0-a547-60cc6c9536af', 'msg_type': 'comm_msg', 'session': 'f8fd1fda-52da-45aa-b2e6-90a7650f0e3a', 'username': '4c80f49d-0a5b-4b83-a405-c265b0e97cf0', 'version': '5.2'}, 'msg_id': 'e1bd3b16-6a50-4cb0-a547-60cc6c9536af', 'msg_type': 'comm_msg', 'parent_header': {}, 'metadata': {}, 'content': {'comm_id': 'd4cf2278f4c740299a7abc968a8aeba2', 'data': {'method': 'custom', 'content': {'event': 'mouse_move', 'x': 174.54337899543378, 'y': 215.0849944765956}}}, 'buffers': []})
# DEBUG:Comm:handle_msg[d4cf2278f4c740299a7abc968a8aeba2]({'header': {'date': datetime.datetime(2025, 1, 5, 12, 24, 27, 711000, tzinfo=tzutc()), 'msg_id': 'a52a32ce-0dc1-4165-9550-f6878543e274', 'msg_type': 'comm_msg', 'session': 'f8fd1fda-52da-45aa-b2e6-90a7650f0e3a', 'username': '4c80f49d-0a5b-4b83-a405-c265b0e97cf0', 'version': '5.2'}, 'msg_id': 'a52a32ce-0dc1-4165-9550-f6878543e274', 'msg_type': 'comm_msg', 'parent_header': {}, 'metadata': {}, 'content': {'comm_id': 'd4cf2278f4c740299a7abc968a8aeba2', 'data': {'method': 'custom', 'content': {'event': 'mouse_move', 'x': 174.90215264187867, 'y': 214.90560749204465}}}, 'buffers': []})
# ...
# DEBUG:Comm:handle_msg[d4cf2278f4c740299a7abc968a8aeba2]({'header': {'date': datetime.datetime(2025, 1, 5, 12, 24, 39, 704000, tzinfo=tzutc()), 'msg_id': '00deb632-ac95-4cf5-9692-701aeeeafb1a', 'msg_type': 'comm_msg', 'session': 'f8fd1fda-52da-45aa-b2e6-90a7650f0e3a', 'username': '4c80f49d-0a5b-4b83-a405-c265b0e97cf0', 'version': '5.2'}, 'msg_id': '00deb632-ac95-4cf5-9692-701aeeeafb1a', 'msg_type': 'comm_msg', 'parent_header': {}, 'metadata': {}, 'content': {'comm_id': 'd4cf2278f4c740299a7abc968a8aeba2', 'data': {'method': 'custom', 'content': {'event': 'mouse_move', 'x': 268.9008480104371, 'y': 226.56576148785675}}}, 'buffers': []})
# DEBUG:Comm:handle_msg[d4cf2278f4c740299a7abc968a8aeba2]({'header': {'date': datetime.datetime(2025, 1, 5, 12, 24, 39, 710000, tzinfo=tzutc()), 'msg_id': '5dcb978d-5aec-45d1-ba1d-735d0841bc3a', 'msg_type': 'comm_msg', 'session': 'f8fd1fda-52da-45aa-b2e6-90a7650f0e3a', 'username': '4c80f49d-0a5b-4b83-a405-c265b0e97cf0', 'version': '5.2'}, 'msg_id': '5dcb978d-5aec-45d1-ba1d-735d0841bc3a', 'msg_type': 'comm_msg', 'parent_header': {}, 'metadata': {}, 'content': {'comm_id': 'd4cf2278f4c740299a7abc968a8aeba2', 'data': {'method': 'custom', 'content': {'event': 'mouse_move', 'x': 268.5420743639922, 'y': 226.92453545695867}}}, 'buffers': []})
# DEBUG:Comm:handle_msg[d4cf2278f4c740299a7abc968a8aeba2]({'header': {'date': datetime.datetime(2025, 1, 5, 12, 24, 39, 719000, tzinfo=tzutc()), 'msg_id': 'df8c7052-181e-4263-ae17-2fce8989b73f', 'msg_type': 'comm_msg', 'session': 'f8fd1fda-52da-45aa-b2e6-90a7650f0e3a', 'username': '4c80f49d-0a5b-4b83-a405-c265b0e97cf0', 'version': '5.2'}, 'msg_id': 'df8c7052-181e-4263-ae17-2fce8989b73f', 'msg_type': 'comm_msg', 'parent_header': {}, 'metadata': {}, 'content': {'comm_id': 'd4cf2278f4c740299a7abc968a8aeba2', 'data': {'method': 'custom', 'content': {'event': 'mouse_move', 'x': 268.36268754076974, 'y': 227.64208339516247}}}, 'buffers': []})
# DEBUG:Comm:handle_msg[d4cf2278f4c740299a7abc968a8aeba2]({'header': {'date': datetime.datetime(2025, 1, 5, 12, 24, 39, 731000, tzinfo=tzutc()), 'msg_id': 'daf9799b-4be8-4677-83de-0d7419991a9a', 'msg_type': 'comm_msg', 'session': 'f8fd1fda-52da-45aa-b2e6-90a7650f0e3a', 'username': '4c80f49d-0a5b-4b83-a405-c265b0e97cf0', 'version': '5.2'}, 'msg_id': 'daf9799b-4be8-4677-83de-0d7419991a9a', 'msg_type': 'comm_msg', 'parent_header': {}, 'metadata': {}, 'content': {'comm_id': 'd4cf2278f4c740299a7abc968a8aeba2', 'data': {'method': 'custom', 'content': {'event': 'mouse_move', 'x': 268.00391389432485, 'y': 228.71840530246823}}}, 'buffers': []})
# DEBUG:Comm:handle_msg[d4cf2278f4c740299a7abc968a8aeba2]({'header': {'date': datetime.datetime(2025, 1, 5, 12, 24, 39, 740000, tzinfo=tzutc()), 'msg_id': '500eef34-06e3-42d7-8bcf-ea3a941b114f', 'msg_type': 'comm_msg', 'session': 'f8fd1fda-52da-45aa-b2e6-90a7650f0e3a', 'username': '4c80f49d-0a5b-4b83-a405-c265b0e97cf0', 'version': '5.2'}, 'msg_id': '500eef34-06e3-42d7-8bcf-ea3a941b114f', 'msg_type': 'comm_msg', 'parent_header': {}, 'metadata': {}, 'content': {'comm_id': 'd4cf2278f4c740299a7abc968a8aeba2', 'data': {'method': 'custom', 'content': {'event': 'mouse_move', 'x': 267.8245270711024, 'y': 229.07717927157012}}}, 'buffers': []})
# DEBUG:Comm:handle_msg[d4cf2278f4c740299a7abc968a8aeba2]({'header': {'date': datetime.datetime(2025, 1, 5, 12, 24, 39, 756000, tzinfo=tzutc()), 'msg_id': '46e9f926-7d5d-4580-b7bc-53bdbbf96b21', 'msg_type': 'comm_msg', 'session': 'f8fd1fda-52da-45aa-b2e6-90a7650f0e3a', 'username': '4c80f49d-0a5b-4b83-a405-c265b0e97cf0', 'version': '5.2'}, 'msg_id': '46e9f926-7d5d-4580-b7bc-53bdbbf96b21', 'msg_type': 'comm_msg', 'parent_header': {}, 'metadata': {}, 'content': {'comm_id': 'd4cf2278f4c740299a7abc968a8aeba2', 'data': {'method': 'custom', 'content': {'event': 'mouse_move', 'x': 267.8245270711024, 'y': 229.615340225223}}}, 'buffers': []})
# DEBUG:Comm:handle_msg[d4cf2278f4c740299a7abc968a8aeba2]({'header': {'date': datetime.datetime(2025, 1, 5, 12, 24, 39, 762000, tzinfo=tzutc()), 'msg_id': '24636119-5e95-4ba8-984b-c7ac21cc745c', 'msg_type': 'comm_msg', 'session': 'f8fd1fda-52da-45aa-b2e6-90a7650f0e3a', 'username': '4c80f49d-0a5b-4b83-a405-c265b0e97cf0', 'version': '5.2'}, 'msg_id': '24636119-5e95-4ba8-984b-c7ac21cc745c', 'msg_type': 'comm_msg', 'parent_header': {}, 'metadata': {}, 'content': {'comm_id': 'd4cf2278f4c740299a7abc968a8aeba2', 'data': {'method': 'custom', 'content': {'event': 'mouse_move', 'x': 267.8245270711024, 'y': 229.79472720977395}}}, 'buffers': []})
# DEBUG:Comm:handle_msg[d4cf2278f4c740299a7abc968a8aeba2]({'header': {'date': datetime.datetime(2025, 1, 5, 12, 24, 39, 776000, tzinfo=tzutc()), 'msg_id': '0675279d-cd44-4fe1-a6fc-d96c93a71bf3', 'msg_type': 'comm_msg', 'session': 'f8fd1fda-52da-45aa-b2e6-90a7650f0e3a', 'username': '4c80f49d-0a5b-4b83-a405-c265b0e97cf0', 'version': '5.2'}, 'msg_id': '0675279d-cd44-4fe1-a6fc-d96c93a71bf3', 'msg_type': 'comm_msg', 'parent_header': {}, 'metadata': {}, 'content': {'comm_id': 'd4cf2278f4c740299a7abc968a8aeba2', 'data': {'method': 'custom', 'content': {'event': 'mouse_move', 'x': 267.8245270711024, 'y': 229.9741141943249}}}, 'buffers': []})
# DEBUG:Comm:handle_msg[d4cf2278f4c740299a7abc968a8aeba2]({'header': {'date': datetime.datetime(2025, 1, 5, 12, 24, 39, 793000, tzinfo=tzutc()), 'msg_id': '354e0a28-2829-45a6-8b6d-aeaa5a49e957', 'msg_type': 'comm_msg', 'session': 'f8fd1fda-52da-45aa-b2e6-90a7650f0e3a', 'username': '4c80f49d-0a5b-4b83-a405-c265b0e97cf0', 'version': '5.2'}, 'msg_id': '354e0a28-2829-45a6-8b6d-aeaa5a49e957', 'msg_type': 'comm_msg', 'parent_header': {}, 'metadata': {}, 'content': {'comm_id': 'd4cf2278f4c740299a7abc968a8aeba2', 'data': {'method': 'custom', 'content': {'event': 'mouse_move', 'x': 268.00391389432485, 'y': 230.15350117887587}}}, 'buffers': []})
# DEBUG:Comm:handle_msg[d4cf2278f4c740299a7abc968a8aeba2]({'header': {'date': datetime.datetime(2025, 1, 5, 12, 24, 39, 803000, tzinfo=tzutc()), 'msg_id': 'c8045c09-939d-41a4-ba67-c0e438348cd9', 'msg_type': 'comm_msg', 'session': 'f8fd1fda-52da-45aa-b2e6-90a7650f0e3a', 'username': '4c80f49d-0a5b-4b83-a405-c265b0e97cf0', 'version': '5.2'}, 'msg_id': 'c8045c09-939d-41a4-ba67-c0e438348cd9', 'msg_type': 'comm_msg', 'parent_header': {}, 'metadata': {}, 'content': {'comm_id': 'd4cf2278f4c740299a7abc968a8aeba2', 'data': {'method': 'custom', 'content': {'event': 'mouse_move', 'x': 268.00391389432485, 'y': 230.33288816342682}}}, 'buffers': []})
# DEBUG:Comm:handle_msg[d4cf2278f4c740299a7abc968a8aeba2]({'header': {'date': datetime.datetime(2025, 1, 5, 12, 24, 39, 812000, tzinfo=tzutc()), 'msg_id': 'cd54cdce-f12b-40fc-971f-211861c87816', 'msg_type': 'comm_msg', 'session': 'f8fd1fda-52da-45aa-b2e6-90a7650f0e3a', 'username': '4c80f49d-0a5b-4b83-a405-c265b0e97cf0', 'version': '5.2'}, 'msg_id': 'cd54cdce-f12b-40fc-971f-211861c87816', 'msg_type': 'comm_msg', 'parent_header': {}, 'metadata': {}, 'content': {'comm_id': 'd4cf2278f4c740299a7abc968a8aeba2', 'data': {'method': 'custom', 'content': {'event': 'mouse_move', 'x': 268.72146118721463, 'y': 230.51227514797776}}}, 'buffers': []})
# DEBUG:Comm:handle_msg[d4cf2278f4c740299a7abc968a8aeba2]({'header': {'date': datetime.datetime(2025, 1, 5, 12, 24, 39, 822000, tzinfo=tzutc()), 'msg_id': 'b8359d12-ba91-499c-891d-2b329f5fd6a1', 'msg_type': 'comm_msg', 'session': 'f8fd1fda-52da-45aa-b2e6-90a7650f0e3a', 'username': '4c80f49d-0a5b-4b83-a405-c265b0e97cf0', 'version': '5.2'}, 'msg_id': 'b8359d12-ba91-499c-891d-2b329f5fd6a1', 'msg_type': 'comm_msg', 'parent_header': {}, 'metadata': {}, 'content': {'comm_id': 'd4cf2278f4c740299a7abc968a8aeba2', 'data': {'method': 'custom', 'content': {'event': 'mouse_move', 'x': 269.0802348336595, 'y': 230.69166213252873}}}, 'buffers': []})
# DEBUG:Comm:handle_msg[d4cf2278f4c740299a7abc968a8aeba2]({'header': {'date': datetime.datetime(2025, 1, 5, 12, 24, 39, 834000, tzinfo=tzutc()), 'msg_id': '1a9cc130-373b-46df-bdef-1e0f6e50b619', 'msg_type': 'comm_msg', 'session': 'f8fd1fda-52da-45aa-b2e6-90a7650f0e3a', 'username': '4c80f49d-0a5b-4b83-a405-c265b0e97cf0', 'version': '5.2'}, 'msg_id': '1a9cc130-373b-46df-bdef-1e0f6e50b619', 'msg_type': 'comm_msg', 'parent_header': {}, 'metadata': {}, 'content': {'comm_id': 'd4cf2278f4c740299a7abc968a8aeba2', 'data': {'method': 'custom', 'content': {'event': 'mouse_move', 'x': 270.1565557729941, 'y': 230.87104911707968}}}, 'buffers': []})
# DEBUG:Comm:handle_msg[d4cf2278f4c740299a7abc968a8aeba2]({'header': {'date': datetime.datetime(2025, 1, 5, 12, 24, 39, 847000, tzinfo=tzutc()), 'msg_id': '1cc82304-df21-4dd2-a043-ca3a5d81cfb0', 'msg_type': 'comm_msg', 'session': 'f8fd1fda-52da-45aa-b2e6-90a7650f0e3a', 'username': '4c80f49d-0a5b-4b83-a405-c265b0e97cf0', 'version': '5.2'}, 'msg_id': '1cc82304-df21-4dd2-a043-ca3a5d81cfb0', 'msg_type': 'comm_msg', 'parent_header': {}, 'metadata': {}, 'content': {'comm_id': 'd4cf2278f4c740299a7abc968a8aeba2', 'data': {'method': 'custom', 'content': {'event': 'mouse_move', 'x': 270.515329419439, 'y': 230.87104911707968}}}, 'buffers': []})
# DEBUG:Comm:handle_msg[d4cf2278f4c740299a7abc968a8aeba2]({'header': {'date': datetime.datetime(2025, 1, 5, 12, 24, 39, 855000, tzinfo=tzutc()), 'msg_id': 'cb056b8b-f832-446b-a720-a14e918303b6', 'msg_type': 'comm_msg', 'session': 'f8fd1fda-52da-45aa-b2e6-90a7650f0e3a', 'username': '4c80f49d-0a5b-4b83-a405-c265b0e97cf0', 'version': '5.2'}, 'msg_id': 'cb056b8b-f832-446b-a720-a14e918303b6', 'msg_type': 'comm_msg', 'parent_header': {}, 'metadata': {}, 'content': {'comm_id': 'd4cf2278f4c740299a7abc968a8aeba2', 'data': {'method': 'custom', 'content': {'event': 'mouse_move', 'x': 271.77103718199606, 'y': 230.87104911707968}}}, 'buffers': []})
# DEBUG:Comm:handle_msg[d4cf2278f4c740299a7abc968a8aeba2]({'header': {'date': datetime.datetime(2025, 1, 5, 12, 24, 39, 872000, tzinfo=tzutc()), 'msg_id': '2156b064-0137-4ea8-83b2-be0365c5e9a8', 'msg_type': 'comm_msg', 'session': 'f8fd1fda-52da-45aa-b2e6-90a7650f0e3a', 'username': '4c80f49d-0a5b-4b83-a405-c265b0e97cf0', 'version': '5.2'}, 'msg_id': '2156b064-0137-4ea8-83b2-be0365c5e9a8', 'msg_type': 'comm_msg', 'parent_header': {}, 'metadata': {}, 'content': {'comm_id': 'd4cf2278f4c740299a7abc968a8aeba2', 'data': {'method': 'custom', 'content': {'event': 'mouse_move', 'x': 272.12981082844095, 'y': 230.87104911707968}}}, 'buffers': []})
# DEBUG:Comm:handle_msg[d4cf2278f4c740299a7abc968a8aeba2]({'header': {'date': datetime.datetime(2025, 1, 5, 12, 24, 39, 878000, tzinfo=tzutc()), 'msg_id': 'a25d017f-0e31-4d87-a2df-57f410b6ed80', 'msg_type': 'comm_msg', 'session': 'f8fd1fda-52da-45aa-b2e6-90a7650f0e3a', 'username': '4c80f49d-0a5b-4b83-a405-c265b0e97cf0', 'version': '5.2'}, 'msg_id': 'a25d017f-0e31-4d87-a2df-57f410b6ed80', 'msg_type': 'comm_msg', 'parent_header': {}, 'metadata': {}, 'content': {'comm_id': 'd4cf2278f4c740299a7abc968a8aeba2', 'data': {'method': 'custom', 'content': {'event': 'mouse_move', 'x': 272.3091976516634, 'y': 230.87104911707968}}}, 'buffers': []})
# DEBUG:Comm:handle_msg[d4cf2278f4c740299a7abc968a8aeba2]({'header': {'date': datetime.datetime(2025, 1, 5, 12, 24, 39, 888000, tzinfo=tzutc()), 'msg_id': 'cd0b5b66-ec8b-4b83-aee5-c737330c4415', 'msg_type': 'comm_msg', 'session': 'f8fd1fda-52da-45aa-b2e6-90a7650f0e3a', 'username': '4c80f49d-0a5b-4b83-a405-c265b0e97cf0', 'version': '5.2'}, 'msg_id': 'cd0b5b66-ec8b-4b83-aee5-c737330c4415', 'msg_type': 'comm_msg', 'parent_header': {}, 'metadata': {}, 'content': {'comm_id': 'd4cf2278f4c740299a7abc968a8aeba2', 'data': {'method': 'custom', 'content': {'event': 'mouse_move', 'x': 273.0267449445532, 'y': 230.69166213252873}}}, 'buffers': []})
# DEBUG:Comm:handle_msg[d4cf2278f4c740299a7abc968a8aeba2]({'header': {'date': datetime.datetime(2025, 1, 5, 12, 24, 39, 912000, tzinfo=tzutc()), 'msg_id': '1a99b425-5905-4207-b02a-413a6e3c3e5d', 'msg_type': 'comm_msg', 'session': 'f8fd1fda-52da-45aa-b2e6-90a7650f0e3a', 'username': '4c80f49d-0a5b-4b83-a405-c265b0e97cf0', 'version': '5.2'}, 'msg_id': '1a99b425-5905-4207-b02a-413a6e3c3e5d', 'msg_type': 'comm_msg', 'parent_header': {}, 'metadata': {}, 'content': {'comm_id': 'd4cf2278f4c740299a7abc968a8aeba2', 'data': {'method': 'custom', 'content': {'event': 'mouse_move', 'x': 273.2061317677756, 'y': 230.69166213252873}}}, 'buffers': []})
# DEBUG:Comm:handle_msg[d4cf2278f4c740299a7abc968a8aeba2]({'header': {'date': datetime.datetime(2025, 1, 5, 12, 24, 39, 954000, tzinfo=tzutc()), 'msg_id': 'c75d0740-b7e4-47c4-9e16-07e3b4fe183c', 'msg_type': 'comm_msg', 'session': 'f8fd1fda-52da-45aa-b2e6-90a7650f0e3a', 'username': '4c80f49d-0a5b-4b83-a405-c265b0e97cf0', 'version': '5.2'}, 'msg_id': 'c75d0740-b7e4-47c4-9e16-07e3b4fe183c', 'msg_type': 'comm_msg', 'parent_header': {}, 'metadata': {}, 'content': {'comm_id': 'd4cf2278f4c740299a7abc968a8aeba2', 'data': {'method': 'custom', 'content': {'event': 'mouse_move', 'x': 273.74429223744295, 'y': 230.69166213252873}}}, 'buffers': []})
# DEBUG:Comm:handle_msg[d4cf2278f4c740299a7abc968a8aeba2]({'header': {'date': datetime.datetime(2025, 1, 5, 12, 24, 39, 960000, tzinfo=tzutc()), 'msg_id': '58a44db6-2283-428f-8afc-bc079189c0ae', 'msg_type': 'comm_msg', 'session': 'f8fd1fda-52da-45aa-b2e6-90a7650f0e3a', 'username': '4c80f49d-0a5b-4b83-a405-c265b0e97cf0', 'version': '5.2'}, 'msg_id': '58a44db6-2283-428f-8afc-bc079189c0ae', 'msg_type': 'comm_msg', 'parent_header': {}, 'metadata': {}, 'content': {'comm_id': 'd4cf2278f4c740299a7abc968a8aeba2', 'data': {'method': 'custom', 'content': {'event': 'mouse_move', 'x': 273.92367906066534, 'y': 230.87104911707968}}}, 'buffers': []})
# DEBUG:Comm:handle_msg[d4cf2278f4c740299a7abc968a8aeba2]({'header': {'date': datetime.datetime(2025, 1, 5, 12, 24, 39, 970000, tzinfo=tzutc()), 'msg_id': '9b18d97e-dfd4-48c6-a21b-8365e0f7ee72', 'msg_type': 'comm_msg', 'session': 'f8fd1fda-52da-45aa-b2e6-90a7650f0e3a', 'username': '4c80f49d-0a5b-4b83-a405-c265b0e97cf0', 'version': '5.2'}, 'msg_id': '9b18d97e-dfd4-48c6-a21b-8365e0f7ee72', 'msg_type': 'comm_msg', 'parent_header': {}, 'metadata': {}, 'content': {'comm_id': 'd4cf2278f4c740299a7abc968a8aeba2', 'data': {'method': 'custom', 'content': {'event': 'mouse_move', 'x': 274.2824527071102, 'y': 230.87104911707968}}}, 'buffers': []})
# DEBUG:Comm:handle_msg[d4cf2278f4c740299a7abc968a8aeba2]({'header': {'date': datetime.datetime(2025, 1, 5, 12, 24, 39, 976000, tzinfo=tzutc()), 'msg_id': '8f772ce2-223f-4616-b9e0-4324bfcefc88', 'msg_type': 'comm_msg', 'session': 'f8fd1fda-52da-45aa-b2e6-90a7650f0e3a', 'username': '4c80f49d-0a5b-4b83-a405-c265b0e97cf0', 'version': '5.2'}, 'msg_id': '8f772ce2-223f-4616-b9e0-4324bfcefc88', 'msg_type': 'comm_msg', 'parent_header': {}, 'metadata': {}, 'content': {'comm_id': 'd4cf2278f4c740299a7abc968a8aeba2', 'data': {'method': 'custom', 'content': {'event': 'mouse_move', 'x': 274.82061317677756, 'y': 231.05043610163065}}}, 'buffers': []})
# DEBUG:Comm:handle_msg[d4cf2278f4c740299a7abc968a8aeba2]({'header': {'date': datetime.datetime(2025, 1, 5, 12, 24, 39, 985000, tzinfo=tzutc()), 'msg_id': '4d85b559-a39c-477b-87a2-dbe7ab003f72', 'msg_type': 'comm_msg', 'session': 'f8fd1fda-52da-45aa-b2e6-90a7650f0e3a', 'username': '4c80f49d-0a5b-4b83-a405-c265b0e97cf0', 'version': '5.2'}, 'msg_id': '4d85b559-a39c-477b-87a2-dbe7ab003f72', 'msg_type': 'comm_msg', 'parent_header': {}, 'metadata': {}, 'content': {'comm_id': 'd4cf2278f4c740299a7abc968a8aeba2', 'data': {'method': 'custom', 'content': {'event': 'mouse_out', 'x': 275, 'y': 231.2298230861816}}}, 'buffers': []})
# DEBUG:Comm:handle_msg[0fd7b00633a44d11991d6a21eae1730e]({'header': {'date': datetime.datetime(2025, 1, 5, 12, 24, 42, 391000, tzinfo=tzutc()), 'msg_id': '80ac4e65-a3c8-4670-9ede-71f9a925c62e', 'msg_type': 'comm_msg', 'session': 'f8fd1fda-52da-45aa-b2e6-90a7650f0e3a', 'username': '4c80f49d-0a5b-4b83-a405-c265b0e97cf0', 'version': '5.2'}, 'msg_id': '80ac4e65-a3c8-4670-9ede-71f9a925c62e', 'msg_type': 'comm_msg', 'parent_header': {}, 'metadata': {}, 'content': {'comm_id': '0fd7b00633a44d11991d6a21eae1730e', 'data': {'method': 'custom', 'content': {'event': 'click'}}}, 'buffers': []})
# INFO:root:saving
# INFO:root:saved
